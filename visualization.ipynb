# %% [markdown]
# <a href="https://colab.research.google.com/github/hannageb/analyzing-top-spotify-tracks/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("spotify_data.csv")
top_artists = df['artist_name'].value_counts()
top_artists.head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>
